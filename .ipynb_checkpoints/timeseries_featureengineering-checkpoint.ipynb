# %% [markdown]
# ![time-features.png](attachment:time-features.png)

# %% [markdown]
# # Load data and change to datetime format

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/ooi.weixin/Documents/Learning Material/9.1 Time-series forecasting (Stock closing price)/data/jetrail/train.csv")
df.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %%
#convert the datecolun into date time format
df['Datetime'] = pd.to_datetime(df['Datetime'],format='%d-%m-%Y %H:%M')

# %% [markdown]
# # Date related features

# %%
#extract year
df['year'] = df['Datetime'].dt.year
df.head()
# Out:
#    ID            Datetime  Count  year
# 0   0 2012-08-25 00:00:00      8  2012
# 1   1 2012-08-25 01:00:00      2  2012
# 2   2 2012-08-25 02:00:00      6  2012
# 3   3 2012-08-25 03:00:00      2  2012
# 4   4 2012-08-25 04:00:00      2  2012

# %%
#extract month
df['month'] = df['Datetime'].dt.month
df.head()
# Out:
#    ID            Datetime  Count  year  month
# 0   0 2012-08-25 00:00:00      8  2012      8
# 1   1 2012-08-25 01:00:00      2  2012      8
# 2   2 2012-08-25 02:00:00      6  2012      8
# 3   3 2012-08-25 03:00:00      2  2012      8
# 4   4 2012-08-25 04:00:00      2  2012      8

# %%
#extract month_year
df['month_year'] = df['Datetime'].dt.to_period('M')
df.head()
# Out:
#    ID            Datetime  Count  year  month month_year
# 0   0 2012-08-25 00:00:00      8  2012      8    2012-08
# 1   1 2012-08-25 01:00:00      2  2012      8    2012-08
# 2   2 2012-08-25 02:00:00      6  2012      8    2012-08
# 3   3 2012-08-25 03:00:00      2  2012      8    2012-08
# 4   4 2012-08-25 04:00:00      2  2012      8    2012-08

# %%
#extract day
df['day'] = df['Datetime'].dt.day
df.head()
# Out:
#    ID            Datetime  Count  year  month month_year  day
# 0   0 2012-08-25 00:00:00      8  2012      8    2012-08   25
# 1   1 2012-08-25 01:00:00      2  2012      8    2012-08   25
# 2   2 2012-08-25 02:00:00      6  2012      8    2012-08   25
# 3   3 2012-08-25 03:00:00      2  2012      8    2012-08   25
# 4   4 2012-08-25 04:00:00      2  2012      8    2012-08   25

# %%
#extract date only
df['date'] = df['Datetime'].dt.date
df.head()
# Out:
#    ID            Datetime  Count  year  month month_year  day        date
# 0   0 2012-08-25 00:00:00      8  2012      8    2012-08   25  2012-08-25
# 1   1 2012-08-25 01:00:00      2  2012      8    2012-08   25  2012-08-25
# 2   2 2012-08-25 02:00:00      6  2012      8    2012-08   25  2012-08-25
# 3   3 2012-08-25 03:00:00      2  2012      8    2012-08   25  2012-08-25
# 4   4 2012-08-25 04:00:00      2  2012      8    2012-08   25  2012-08-25

# %%
#extract weekday of a date in numeric forms
df['days_in_week'] = df['Datetime'].dt.weekday
#df['days_in_week'] = df['Datetime'].dt.dayofweek
df.head()
#0 Monday
#6 Sunday
# Out:
#    ID            Datetime  Count  year  month month_year  day        date  \
# 0   0 2012-08-25 00:00:00      8  2012      8    2012-08   25  2012-08-25
# 1   1 2012-08-25 01:00:00      2  2012      8    2012-08   25  2012-08-25
# 2   2 2012-08-25 02:00:00      6  2012      8    2012-08   25  2012-08-25
# 3   3 2012-08-25 03:00:00      2  2012      8    2012-08   25  2012-08-25
# 4   4 2012-08-25 04:00:00      2  2012      8    2012-08   25  2012-08-25
#
#    days_in_week
# 0             5
# 1             5
# 2             5
# 3             5
# 4             5

# %%
#extract weekday of a date in word forms
df['days_in_week_word'] = df['Datetime'].dt.day_name(locale = 'English') 
df.head()
# Out:
#    ID            Datetime  Count  year  month month_year  day        date  \
# 0   0 2012-08-25 00:00:00      8  2012      8    2012-08   25  2012-08-25
# 1   1 2012-08-25 01:00:00      2  2012      8    2012-08   25  2012-08-25
# 2   2 2012-08-25 02:00:00      6  2012      8    2012-08   25  2012-08-25
# 3   3 2012-08-25 03:00:00      2  2012      8    2012-08   25  2012-08-25
# 4   4 2012-08-25 04:00:00      2  2012      8    2012-08   25  2012-08-25
#
#    days_in_week days_in_week_word
# 0             5          Saturday
# 1             5          Saturday
# 2             5          Saturday
# 3             5          Saturday
# 4             5          Saturday

# %% [markdown]
# # Time-based features
#
# Look into:
# 1. business hour/ non-business hour
# 2. morning, afternoon, evening, etc

# %%
#extract time only
df['time'] = df['Datetime'].dt.time
df.head()
# Out:
#    ID            Datetime  Count  year  month month_year  day        date  \
# 0   0 2012-08-25 00:00:00      8  2012      8    2012-08   25  2012-08-25
# 1   1 2012-08-25 01:00:00      2  2012      8    2012-08   25  2012-08-25
# 2   2 2012-08-25 02:00:00      6  2012      8    2012-08   25  2012-08-25
# 3   3 2012-08-25 03:00:00      2  2012      8    2012-08   25  2012-08-25
# 4   4 2012-08-25 04:00:00      2  2012      8    2012-08   25  2012-08-25
#
#    days_in_week days_in_week_word      time
# 0             5          Saturday  00:00:00
# 1             5          Saturday  01:00:00
# 2             5          Saturday  02:00:00
# 3             5          Saturday  03:00:00
# 4             5          Saturday  04:00:00

# %%
#extract hour
df['hour'] = df['Datetime'].dt.hour
df.head()
# Out:
#    ID            Datetime  Count  year  month month_year  day        date  \
# 0   0 2012-08-25 00:00:00      8  2012      8    2012-08   25  2012-08-25
# 1   1 2012-08-25 01:00:00      2  2012      8    2012-08   25  2012-08-25
# 2   2 2012-08-25 02:00:00      6  2012      8    2012-08   25  2012-08-25
# 3   3 2012-08-25 03:00:00      2  2012      8    2012-08   25  2012-08-25
# 4   4 2012-08-25 04:00:00      2  2012      8    2012-08   25  2012-08-25
#
#    days_in_week days_in_week_word      time  hour
# 0             5          Saturday  00:00:00     0
# 1             5          Saturday  01:00:00     1
# 2             5          Saturday  02:00:00     2
# 3             5          Saturday  03:00:00     3
# 4             5          Saturday  04:00:00     4

# %%
#extract minute
df['minute'] = df['Datetime'].dt.minute
df.head()
# Out:
#    ID            Datetime  Count  year  month month_year  day        date  \
# 0   0 2012-08-25 00:00:00      8  2012      8    2012-08   25  2012-08-25
# 1   1 2012-08-25 01:00:00      2  2012      8    2012-08   25  2012-08-25
# 2   2 2012-08-25 02:00:00      6  2012      8    2012-08   25  2012-08-25
# 3   3 2012-08-25 03:00:00      2  2012      8    2012-08   25  2012-08-25
# 4   4 2012-08-25 04:00:00      2  2012      8    2012-08   25  2012-08-25
#
#    days_in_week days_in_week_word      time  hour  minute
# 0             5          Saturday  00:00:00     0       0
# 1             5          Saturday  01:00:00     1       0
# 2             5          Saturday  02:00:00     2       0
# 3             5          Saturday  03:00:00     3       0
# 4             5          Saturday  04:00:00     4       0

# %%
#extract minute
df['second'] = df['Datetime'].dt.second
df.head()
# Out:
#    ID            Datetime  Count  year  month month_year  day        date  \
# 0   0 2012-08-25 00:00:00      8  2012      8    2012-08   25  2012-08-25
# 1   1 2012-08-25 01:00:00      2  2012      8    2012-08   25  2012-08-25
# 2   2 2012-08-25 02:00:00      6  2012      8    2012-08   25  2012-08-25
# 3   3 2012-08-25 03:00:00      2  2012      8    2012-08   25  2012-08-25
# 4   4 2012-08-25 04:00:00      2  2012      8    2012-08   25  2012-08-25
#
#    days_in_week days_in_week_word      time  hour  minute  second
# 0             5          Saturday  00:00:00     0       0       0
# 1             5          Saturday  01:00:00     1       0       0
# 2             5          Saturday  02:00:00     2       0       0
# 3             5          Saturday  03:00:00     3       0       0
# 4             5          Saturday  04:00:00     4       0       0

# %% [markdown]
# # Lag features
# = previous days' data/ target variables
#
# The lag value chose will be depend on the
# 1. correlation of individual values with its past values.
# 2. ACF (Autocorrelation function): measure the correlation between time series and the laged version of itself.
# 3. PACF (Partial AutocrrelationFunction): measure of the correlation between the time series with a lagged version of itself but after eliminating the variations already explained by the intervening comparisons.
#
# ie. If the series has a weekly trend, which means the value last Monday can be used to predict the value for this Monday, you should create lag features for seven days.
#
# If we train a linear regression model, it will assign appropriate weights (or coefficients) to the lag features.
#
# #Note: the number of times you shift, the same number of values will be reduced from the data. You would see some rows with NaNs at the start. That’s because the first observation has no lag. You’ll need to discard these rows from the training data.

# %% [markdown]
# # Rolling window feature
#
# 1. Get sum/min/max/average value of a constant range of window.
# 2. USe weighted average by assignning higher weights to recent features.

# %% [markdown]
# # Expanding window feature
#
# = advanced version of roling window technique where it takes all the past values into account

# %%
df['expanding_mean'] = df['Count'].expanding(2).mean()
df = df[['Datetime','Count', 'expanding_mean']]

df.head()
# Out:
#              Datetime  Count  expanding_mean
# 0 2012-08-25 00:00:00      8             NaN
# 1 2012-08-25 01:00:00      2        5.000000
# 2 2012-08-25 02:00:00      6        5.333333
# 3 2012-08-25 03:00:00      2        4.500000
# 4 2012-08-25 04:00:00      2        4.000000

# %% [markdown]
# # Domain-specific features
#
# ie. for sales related data; will weather/ public holiday affect the sales? If yes, include externl datasets (weather/holiday lists as a feature)

# %% [markdown]
# # Extra: validation splitting technique for time series
#
# data should not be shuffle in time-seris data

# %%
#check the timeframe
df['Datetime'].min(), df['Datetime'].max(), (df['Datetime'].max() -df['Datetime'].min())
# Out:
# (Timestamp('2012-08-25 00:00:00'),
#  Timestamp('2014-09-25 23:00:00'),
#  Timedelta('761 days 23:00:00'))

# %%
#split train-validation dataset
df.index = df.Datetime
Train=df.loc['2012-08-25':'2014-06-24'] 
valid=df.loc['2014-06-25':'2014-09-25']

Train.shape, valid.shape
# Out:
# ((16056, 3), (2232, 3))
